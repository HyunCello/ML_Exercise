# %%
cd /content/drive/My Drive/labr/pytorch/zerotoall
# Out:
# /content/drive/My Drive/labr/pytorch/zerotoall

# %%
from torch import nn, optim, from_numpy
import numpy as np

xy = np.loadtxt('./data/diabetes.csv', delimiter=',', dtype=np.float32)
x_data = from_numpy(xy[:,0:-1])
y_data = from_numpy(xy[:, [-1]])
print(f'X\'s shape: {x_data.shape} | Y\'s shape: {y_data.shape}')
# Out:
# X's shape: torch.Size([759, 8]) | Y's shape: torch.Size([759, 1])

# %%
class Model(nn.Module):
  def __init__(self):
    super(Model, self).__init__()
    self.l1 = nn.Linear(8,6)
    self.l2 = nn.Linear(6,4)
    self.l3 = nn.Linear(4,6)
    self.l4 = nn.Linear(6,4)
    self.l5 = nn.Linear(4,1)

    self.sigmoid = nn.Sigmoid()
  
  def forward(self, x):
    out1 = self.sigmoid(self.l1(x))
    out2 = self.sigmoid(self.l2(out1))
    out3 = self.sigmoid(self.l3(out2))
    out4 = self.sigmoid(self.l4(out3))
    y_pred = self.sigmoid(self.l5(out4))
    return y_pred

# %%
model = Model()

criterion = nn.BCELoss(reduction='mean')
optimizer = optim.SGD(model.parameters(), lr=0.01)

for epoch in range(100):
  
  y_pred = model(x_data)

  loss = criterion(y_pred, y_data)
  print(f'Epoch: {epoch + 1}/100 | Loss: {loss.item():.4f}')

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

print(f'Epoch: {epoch + 1}/100 | Loss: {loss.item():.4f}')
# Out:
# Epoch: 1/100 | Loss: 0.6556
# Epoch: 2/100 | Loss: 0.6555
# Epoch: 3/100 | Loss: 0.6554
# Epoch: 4/100 | Loss: 0.6553
# Epoch: 5/100 | Loss: 0.6552
# Epoch: 6/100 | Loss: 0.6551
# Epoch: 7/100 | Loss: 0.6550
# Epoch: 8/100 | Loss: 0.6549
# Epoch: 9/100 | Loss: 0.6548
# Epoch: 10/100 | Loss: 0.6547
# Epoch: 11/100 | Loss: 0.6547
# Epoch: 12/100 | Loss: 0.6546
# Epoch: 13/100 | Loss: 0.6545
# Epoch: 14/100 | Loss: 0.6544
# Epoch: 15/100 | Loss: 0.6543
# Epoch: 16/100 | Loss: 0.6542
# Epoch: 17/100 | Loss: 0.6541
# Epoch: 18/100 | Loss: 0.6541
# Epoch: 19/100 | Loss: 0.6540
# Epoch: 20/100 | Loss: 0.6539
# Epoch: 21/100 | Loss: 0.6538
# Epoch: 22/100 | Loss: 0.6537
# Epoch: 23/100 | Loss: 0.6537
# Epoch: 24/100 | Loss: 0.6536
# Epoch: 25/100 | Loss: 0.6535
# Epoch: 26/100 | Loss: 0.6534
# Epoch: 27/100 | Loss: 0.6534
# Epoch: 28/100 | Loss: 0.6533
# Epoch: 29/100 | Loss: 0.6532
# Epoch: 30/100 | Loss: 0.6531
# Epoch: 31/100 | Loss: 0.6531
# Epoch: 32/100 | Loss: 0.6530
# Epoch: 33/100 | Loss: 0.6529
# Epoch: 34/100 | Loss: 0.6528
# Epoch: 35/100 | Loss: 0.6528
# Epoch: 36/100 | Loss: 0.6527
# Epoch: 37/100 | Loss: 0.6526
# Epoch: 38/100 | Loss: 0.6526
# Epoch: 39/100 | Loss: 0.6525
# Epoch: 40/100 | Loss: 0.6524
# Epoch: 41/100 | Loss: 0.6524
# Epoch: 42/100 | Loss: 0.6523
# Epoch: 43/100 | Loss: 0.6522
# Epoch: 44/100 | Loss: 0.6522
# Epoch: 45/100 | Loss: 0.6521
# Epoch: 46/100 | Loss: 0.6520
# Epoch: 47/100 | Loss: 0.6520
# Epoch: 48/100 | Loss: 0.6519
# Epoch: 49/100 | Loss: 0.6519
# Epoch: 50/100 | Loss: 0.6518
# Epoch: 51/100 | Loss: 0.6517
# Epoch: 52/100 | Loss: 0.6517
# Epoch: 53/100 | Loss: 0.6516
# Epoch: 54/100 | Loss: 0.6516
# Epoch: 55/100 | Loss: 0.6515
# Epoch: 56/100 | Loss: 0.6514
# Epoch: 57/100 | Loss: 0.6514
# Epoch: 58/100 | Loss: 0.6513
# Epoch: 59/100 | Loss: 0.6513
# Epoch: 60/100 | Loss: 0.6512
# Epoch: 61/100 | Loss: 0.6512
# Epoch: 62/100 | Loss: 0.6511
# Epoch: 63/100 | Loss: 0.6511
# Epoch: 64/100 | Loss: 0.6510
# Epoch: 65/100 | Loss: 0.6509
# Epoch: 66/100 | Loss: 0.6509
# Epoch: 67/100 | Loss: 0.6508
# Epoch: 68/100 | Loss: 0.6508
# Epoch: 69/100 | Loss: 0.6507
# Epoch: 70/100 | Loss: 0.6507
# Epoch: 71/100 | Loss: 0.6506
# Epoch: 72/100 | Loss: 0.6506
# Epoch: 73/100 | Loss: 0.6505
# Epoch: 74/100 | Loss: 0.6505
# Epoch: 75/100 | Loss: 0.6504
# Epoch: 76/100 | Loss: 0.6504
# Epoch: 77/100 | Loss: 0.6504
# Epoch: 78/100 | Loss: 0.6503
# Epoch: 79/100 | Loss: 0.6503
# Epoch: 80/100 | Loss: 0.6502
# Epoch: 81/100 | Loss: 0.6502
# Epoch: 82/100 | Loss: 0.6501
# Epoch: 83/100 | Loss: 0.6501
# Epoch: 84/100 | Loss: 0.6500
# Epoch: 85/100 | Loss: 0.6500
# Epoch: 86/100 | Loss: 0.6499
# Epoch: 87/100 | Loss: 0.6499
# Epoch: 88/100 | Loss: 0.6499
# Epoch: 89/100 | Loss: 0.6498
# Epoch: 90/100 | Loss: 0.6498
# Epoch: 91/100 | Loss: 0.6497
# Epoch: 92/100 | Loss: 0.6497
# Epoch: 93/100 | Loss: 0.6497
# Epoch: 94/100 | Loss: 0.6496
# Epoch: 95/100 | Loss: 0.6496
# Epoch: 96/100 | Loss: 0.6495
# Epoch: 97/100 | Loss: 0.6495
# Epoch: 98/100 | Loss: 0.6495
# Epoch: 99/100 | Loss: 0.6494
# Epoch: 100/100 | Loss: 0.6494
# Epoch: 100/100 | Loss: 0.6494
